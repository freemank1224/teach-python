# %% [markdown]
# ## Review: yula:lesson2
#
# ### 自动驾驶系统
# 1. **代码结构**：使用了 `if-elif-else` 条件语句来处理燃料水平的不同情况，非常合理。对于初学者来说，这是一个很好的练习。
#    - **评分**: 5/5
#
# 2. **输出信息**：中文提示信息清晰明了，能够直观地反映当前状态。
#    - **建议**: 尝试在代码中加入注释，说明每个 `if-elif-else` 分支的作用。
#
# ### 循环检测系统
# 1. **判断条件**：使用了 `and` 逻辑运算符来合并多个条件，这种方法非常简洁。
#    - **评分**: 5/5
#
# 2. **循环结构**：使用 `while` 循环实现高度的增加，代码简单易懂。
#    - **建议**: 可以添加一些条件来模拟真实飞行中可能遇到的障碍物，使程序更具挑战性。
#
# 3. **输出信息**：在循环中使用 `f-string` 格式化字符串输出高度，这是一个好习惯。
#    - **评分**: 5/5
#
# ### 检查系统
# 1. **列表遍历**：使用 `for` 循环逐一检查系统，非常直观。
#    - **评分**: 5/5
#
# 2. **输出信息**：打印每个系统检查的结果，使得程序更具交互性。
#    - **建议**: 可以增加一个随机因素，模拟某些系统可能需要重新检查的情况。
#
# ### 交互式导航系统
# 1. **输入处理**：使用 `input()` 获取用户指令，并通过条件判断来执行不同操作。
#    - **评分**: 4/5
#
# 2. **选项提示**：列出目的地并让用户选择，提高了交互性。
#    - **建议**: 可以加入错误处理机制，以应对用户输入非数字或超出范围的情况。
#
# 3. **循环航行**：使用 `while` 循环模拟飞行过程，并打印飞行距离。
#    - **建议**: 可以增加一些随机事件，比如天气变化等，使得代码更具实际应用性。
#
# ### 总体评价
# - 你的代码结构清晰、逻辑简单易懂。在交互式程序设计上表现出色。
# - 希望你能继续探索更多 Python 的特性，如错误处理和模块化编程。
#
# ---
